# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('canada_per_capita_income.csv')

# %%
df.head(6)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583
# 5  1975              5998.144346

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize=((24, 8)))
sns.lineplot(data=df, x='year', y='per capita income (US$)')
# Out:
# <AxesSubplot:xlabel='year', ylabel='per capita income (US$)'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 880.0 bytes

# %%
fig = plt.figure(figsize=((24, 8)))
sns.barplot(data=df, x='year', y='per capita income (US$)')
# Out:
# <AxesSubplot:xlabel='year', ylabel='per capita income (US$)'>

# %%
x = np.array(df['year']).reshape(-1, 1)

# %%
y = df['per capita income (US$)']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression().fit(x, y)

# %%
predicted_income_2025 = lr.predict([[2025]])
print("Predicted per capita income in 2025:", predicted_income_2025[0])
# Out:
# Predicted per capita income in 2025: 45431.01947053103

# %%
# Done
